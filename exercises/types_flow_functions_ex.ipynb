# %% [markdown]
# <h2>Homework 2:</h2>
# <h2>Python Data Types, Control Flow, and Functions</h2>

# %% [markdown]
# <h3>Part A: Python Data Types</h3>

# %% [markdown]
# <h4>1. What Python data type would you use to store:</h4>
#
# a. Your age
#
# b. Your name
#
# c. Whether it is raining
#
# d. Your favorite fruits

# %% [markdown]
# <h4>2. What is the data type of each of the following?</h4>
#
# 42
#
# "Hello"
#
# False
#
# 3.14
#
# ["Red", "Blue"]

# %% [markdown]
# <h4>3. Which of these are strings?</h4>
#
# 25
#
# "Python"
#
# "10"
#
# True
#
# "Computer"

# %% [markdown]
# <h4>4. Write one example of:</h4>
#
# an integer
#
# a float
#
# a string
#
# a Boolean

# %% [markdown]
# <h3>Part B: Control Flow</h3>

# %% [markdown]
# <h4>5. What is the purpose of an if statement?</h4>

# %% [markdown]
# <h4>6. What keyword lets you check another condition if the first one is false?</h4>

# %% [markdown]
# <h4>7. What keyword runs when none of the earlier conditions are true?</h4>

# %% [markdown]
# <h3>Part C: Predict the Output</h3>

# %% [markdown]
# <h4>8. What will the following program output?</h4>

# %%
temperature = 24

if temperature >= 24:
    print("Let's go swimming.")
else:
    print("Let's walk along the promenade.")

# %% [markdown]
# <h4>9. What will the following program output?</h4>

# %%
score = 55

if score >= 90:
    print("A")
elif score >= 70:
    print("B")
else:
    print("Keep practicing!")

# %% [markdown]
# <h3>Part D: Writing Programs</h3>

# %% [markdown]
# <h4>10. Program Assignment</h4>
#
# Write a program that asks the user for their name and prints:
#
# ```text
# Hello, <name>!
# ```

# %% [markdown]
# <h4>11. Program Assignment</h4>
#
# Write a program that:
#
# 1. asks for the user's age
#
# 2. prints "You can ride the roller coaster!" if the age is 10 or older
#
# 3. otherwise prints "You are not old enough yet."

# %% [markdown]
# <h4>12. Program Assignment</h4>
#
# Write a function named greet() that prints:
#
# Welcome to Python!
#
# Then call the function.

# %% [markdown]
# <h4>13. Program Assignment</h4>
#
# Write a function called double_number(number) that returns twice the number.
#
# Example:
#
# double_number(4)
#
# Output: <br>
# 8

# %% [markdown]
# <h4>14. Programming Assignment</h4>
#
# Write a program that:
#
# 1. Asks the user for their favorite animal
#
# 2. Stores the answer in a variable
#
# 3. Prints:
#
# ```text
#    My favorite animal is <animal>.
# ```

# %% [markdown]
# <h4>15. Programming Assignment</h4>
#
# Write a program that asks the user to enter a number.
#
# If the number is:
#
# greater than 0, print "Positive" <br>
# less than 0, print "Negative" <br>
# exactly 0, print "Zero"
#
# Use if, elif, and else.
